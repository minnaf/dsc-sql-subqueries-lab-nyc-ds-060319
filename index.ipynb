# %% [markdown]
# # SQL Subqueries - Lab
#
# ## Introduction
#
# Now that you've seen how subqueries work, it's time to get some practice writing them! Not all of the queries will require subqueries, but all will be a bit more complex and require some thought and review about aggregates, grouping, ordering, filtering, joins and subqueries. Good luck!
#
# ## Objectives
#
# You will be able to:
#
# * Write subqueries to decompose complex queries
#
# ## CRM Database Schema
#
# Once again, here's the schema for the CRM database you'll continue to practice with.
#
# <img src="images/Database-Schema.png" width="600">
#
# ## Connect to the Database
#
# As usual, start by importing the necessary packages and connecting to the database **data.sqlite**.

# %%
#Your code here; import the necessary packages
import pandas as pd 
import sqlite3

conn = sqlite3.connect("data.sqlite")
c = conn.cursor()

# %%
#Your code here; create the connection and cursor

# %% [markdown]
# ## Select the Average Number of Orders on a Product by Product Basis

# %%
#Your code here; use a subquery. No join will be necessary.


c.execute("""select AVG(numOrders)
                    from (select productCode,
                                 count(distinct orderNumber) as numOrders
                                 from products
                                 join orderdetails
                                 using(productCode)
                                 group by 1
                         );
          """
         )

df = pd.DataFrame(c.fetchall())
df.columns = [x[0] for x in c.description]
df
# Out:
#    AVG(numOrders)
# 0       27.486239

# %% [markdown]
# ## Write an Equivalent Query using a Subquery
#
# ```SQL
# select customerNumber,
#        contactLastName,
#        contactFirstName
#        from customers
#        join orders
#        using(customerNumber)
#        where orderDate = '2003-01-31';
# ```

# %%
#Your code here; use a subquery. No join will be necessary.

# %% [markdown]
# ## Select the Total Number of Orders for Each Product Name
#
# Sort the results by the total number of items sold for that product.

# %%
#Your code here
c.execute(""" SELECT * FROM products 
          JOIN orderdetails USING(productCode) 
          GROUP BY productCode


""")






df = pd.DataFrame(c.fetchall())
df.columns = [x[0] for x in c.description]
df
# Out:
#      productCode                            productName   productLine  \
# 0       S10_1678  1969 Harley Davidson Ultimate Chopper   Motorcycles
# 1       S10_1678  1969 Harley Davidson Ultimate Chopper   Motorcycles
# 2       S10_1678  1969 Harley Davidson Ultimate Chopper   Motorcycles
# 3       S10_1678  1969 Harley Davidson Ultimate Chopper   Motorcycles
# 4       S10_1678  1969 Harley Davidson Ultimate Chopper   Motorcycles
# 5       S10_1678  1969 Harley Davidson Ultimate Chopper   Motorcycles
# 6       S10_1678  1969 Harley Davidson Ultimate Chopper   Motorcycles
# 7       S10_1678  1969 Harley Davidson Ultimate Chopper   Motorcycles
# 8       S10_1678  1969 Harley Davidson Ultimate Chopper   Motorcycles
# 9       S10_1678  1969 Harley Davidson Ultimate Chopper   Motorcycles
# 10      S10_1678  1969 Harley Davidson Ultimate Chopper   Motorcycles
# 11      S10_1678  1969 Harley Davidson Ultimate Chopper   Motorcycles
# 12      S10_1678  1969 Harley Davidson Ultimate Chopper   Motorcycles
# 13      S10_1678  1969 Harley Davidson Ultimate Chopper   Motorcycles
# 14      S10_1678  1969 Harley Davidson Ultimate Chopper   Motorcycles
# 15      S10_1678  1969 Harley Davidson Ultimate Chopper   Motorcycles
# 16      S10_1678  1969 Harley Davidson Ultimate Chopper   Motorcycles
# 17      S10_1678  1969 Harley Davidson Ultimate Chopper   Motorcycles
# 18      S10_1678  1969 Harley Davidson Ultimate Chopper   Motorcycles
# 19      S10_1678  1969 Harley Davidson Ultimate Chopper   Motorcycles
# 20      S10_1678  1969 Harley Davidson Ultimate Chopper   Motorcycles
# 21      S10_1678  1969 Harley Davidson Ultimate Chopper   Motorcycles
# 22      S10_1678  1969 Harley Davidson Ultimate Chopper   Motorcycles
# 23      S10_1678  1969 Harley Davidson Ultimate Chopper   Motorcycles
# 24      S10_1678  1969 Harley Davidson Ultimate Chopper   Motorcycles
# 25      S10_1678  1969 Harley Davidson Ultimate Chopper   Motorcycles
# 26      S10_1678  1969 Harley Davidson Ultimate Chopper   Motorcycles
# 27      S10_1678  1969 Harley Davidson Ultimate Chopper   Motorcycles
# 28      S10_1949               1952 Alpine Renault 1300  Classic Cars
# 29      S10_1949               1952 Alpine Renault 1300  Classic Cars
# ...          ...                                    ...           ...
# 2966    S72_1253                       Boeing X-32A JSF        Planes
# 2967    S72_1253                       Boeing X-32A JSF        Planes
# 2968    S72_1253                       Boeing X-32A JSF        Planes
# 2969    S72_3212                             Pont Yacht         Ships
# 2970    S72_3212                             Pont Yacht         Ships
# 2971    S72_3212                             Pont Yacht         Ships
# 2972    S72_3212                             Pont Yacht         Ships
# 2973    S72_3212                             Pont Yacht         Ships
# 2974    S72_3212                             Pont Yacht         Ships
# 2975    S72_3212                             Pont Yacht         Ships
# 2976    S72_3212                             Pont Yacht         Ships
# 2977    S72_3212                             Pont Yacht         Ships
# 2978    S72_3212                             Pont Yacht         Ships
# 2979    S72_3212                             Pont Yacht         Ships
# 2980    S72_3212                             Pont Yacht         Ships
# 2981    S72_3212                             Pont Yacht         Ships
# 2982    S72_3212                             Pont Yacht         Ships
# 2993         1:72     Unimax Art Galleries
# 2994         1:72     Unimax Art Galleries
# 2995         1:72     Unimax Art Galleries
#
#                                      productDescription quantityInStock  \
# 0     This replica features working kickstand, front...            7933
# 1     This replica features working kickstand, front...            7933
# 2     This replica features working kickstand, front...            7933
# 3     This replica features working kickstand, front...            7933
# 4     This replica features working kickstand, front...            7933
# 5     This replica features working kickstand, front...            7933
# 6     This replica features working kickstand, front...            7933
# 7     This replica features working kickstand, front...            7933
# 8     This replica features working kickstand, front...            7933
# 9     This replica features working kickstand, front...            7933
# 10    This replica features working kickstand, front...            7933
# 11    This replica features working kickstand, front...            7933
# 12    This replica features working kickstand, front...            7933
# 13    This replica features working kickstand, front...            7933
# 14    This replica features working kickstand, front...            7933
# 15    This replica features working kickstand, front...            7933
# 16    This replica features working kickstand, front...            7933
# 17    This replica features working kickstand, front...            7933
# 18    This replica features working kickstand, front...            7933
# 19    This replica features working kickstand, front...            7933
# 20    This replica features working kickstand, front...            7933
# 21    This replica features working kickstand, front...            7933
# 22    This replica features working kickstand, front...            7933
# 23    This replica features working kickstand, front...            7933
# 24    This replica features working kickstand, front...            7933
# 25    This replica features working kickstand, front...            7933
# 26    This replica features working kickstand, front...            7933
# 27    This replica features working kickstand, front...            7933
# 28    Turnable front wheels; steering function; deta...            7305
# 29    Turnable front wheels; steering function; deta...            7305
# ...                                                 ...             ...
# 2966  10" Wingspan with retractable landing gears.Co...            4857
# 2967  10" Wingspan with retractable landing gears.Co...            4857
# 2968  10" Wingspan with retractable landing gears.Co...            4857
# 2969  Measures 38 inches Long x 33 3/4 inches High. ...             414
# 2970  Measures 38 inches Long x 33 3/4 inches High. ...             414
# 2971  Measures 38 inches Long x 33 3/4 inches High. ...             414
# 2972  Measures 38 inches Long x 33 3/4 inches High. ...             414
# 2973  Measures 38 inches Long x 33 3/4 inches High. ...             414
# 2974  Measures 38 inches Long x 33 3/4 inches High. ...             414
# 2975  Measures 38 inches Long x 33 3/4 inches High. ...             414
# 2976  Measures 38 inches Long x 33 3/4 inches High. ...             414
# 2977  Measures 38 inches Long x 33 3/4 inches High. ...             414
# 2978  Measures 38 inches Long x 33 3/4 inches High. ...             414
# 2979  Measures 38 inches Long x 33 3/4 inches High. ...             414
# 2980  Measures 38 inches Long x 33 3/4 inches High. ...             414
# 2981  Measures 38 inches Long x 33 3/4 inches High. ...             414
# 2982  Measures 38 inches Long x 33 3/4 inches High. ...             414
# 2983  Measures 38 inches Long x 33 3/4 inches High. ...             414
# 2984  Measures 38 inches Long x 33 3/4 inches High. ...             414
# 2985  Measures 38 inches Long x 33 3/4 inches High. ...             414
# 2986  Measures 38 inches Long x 33 3/4 inches High. ...             414
# 2987  Measures 38 inches Long x 33 3/4 inches High. ...             414
# 2988  Measures 38 inches Long x 33 3/4 inches High. ...             414
# 2989  Measures 38 inches Long x 33 3/4 inches High. ...             414
# 2990  Measures 38 inches Long x 33 3/4 inches High. ...             414
# 2991  Measures 38 inches Long x 33 3/4 inches High. ...             414
# 2992  Measures 38 inches Long x 33 3/4 inches High. ...             414
# 2993  Measures 38 inches Long x 33 3/4 inches High. ...             414
# 2994  Measures 38 inches Long x 33 3/4 inches High. ...             414
# 2995  Measures 38 inches Long x 33 3/4 inches High. ...             414
#
#      buyPrice    MSRP orderNumber quantityOrdered priceEach orderLineNumber
# 0       48.81   95.70       10107              30     81.35               2
# 1       48.81   95.70       10121              34     86.13               5
# 2       48.81   95.70       10134              41     90.92               2
# 3       48.81   95.70       10145              45     76.56               6
# 4       48.81   95.70       10159              49     81.35              14
# 5       48.81   95.70       10168              36     94.74               1
# 6       48.81   95.70       10180              29     76.56               9
# 7       48.81   95.70       10188              48     95.70               1
# 8       48.81   95.70       10201              22     82.30               2
# 9       48.81   95.70       10211              41     90.92              14
# 10      48.81   95.70       10223              37     80.39               1
# 11      48.81   95.70       10237              23     91.87               7
# 12      48.81   95.70       10251              59     93.79               2
# 13      48.81   95.70       10263              34     89.00               2
# 14      48.81   95.70       10275              45     81.35               1
# 15      48.81   95.70       10285              36     95.70               6
# 16      48.81   95.70       10299              23     76.56               9
# 17      48.81   95.70       10309              41     94.74               5
# 18      48.81   95.70       10318              46     84.22               1
# 19      48.81   95.70       10329              42     80.39               1
# 20      48.81   95.70       10341              41     84.22               9
# 21      48.81   95.70       10354              42     84.22               6
# 22      48.81   95.70       10361              20     92.83              13
# 23      48.81   95.70       10375              21     76.56              12
# 24      48.81   95.70       10388              42     80.39               4
# 25      48.81   95.70       10399              40     77.52               8
# 26      48.81   95.70       10403              24     85.17               7
# 27      48.81   95.70       10417              66     79.43               2
# 28      98.58  214.30       10103              26    214.30              11
# 29      98.58  214.30       10112              29    197.16               1
# ...       ...     ...         ...             ...       ...             ...
# 2966    32.77   49.66       10398              34     41.22               1
# 2967    32.77   49.66       10400              20     41.71               4
# 2968    32.77   49.66       10415              42     43.20               3
# 2969    33.30   54.60       10105              25     44.77               8
# 2970    33.30   54.60       10117              50     52.42               2
# 2971    33.30   54.60       10129              32     44.23               8
# 2972    33.30   54.60       10142              39     46.96               5
# 2973    33.30   54.60       10153              50     51.87               4
# 2974    33.30   54.60       10167              38     43.68              15
# 2975    33.30   54.60       10177              40     52.96               6
# 2976    33.30   54.60       10185              28     47.50               6
# 2977    33.30   54.60       10197              42     48.59              12
# 2978    33.30   54.60       10208              42     48.05               6
# 2979    33.30   54.60       10222              36     48.59              18
# 2980    33.30   54.60       10232              24     48.59               3
# 2981    33.30   54.60       10248              23     53.51               9
# 2982    33.30   54.60       10261              29     43.68               7
# 2983    33.30   54.60       10273              37     51.32              10
# 2984    33.30   54.60       10283              33     49.14              12
# 2985    33.30   54.60       10293              32     51.32               1
# 2986    33.30   54.60       10306              35     48.05               6
# 2987    33.30   54.60       10315              40     51.32               5
# 2988    33.30   54.60       10327              37     48.05               4
# 2989    33.30   54.60       10337              42     49.14               5
# 2990    33.30   54.60       10350              20     48.05              15
# 2991    33.30   54.60       10360              31     54.05              11
# 2992    33.30   54.60       10373              29     48.05               1
# 2993    33.30   54.60       10386              43     52.42               4
# 2994    33.30   54.60       10397              34     52.96               1
# 2995    33.30   54.60       10414              47     54.60               9
#
# [2996 rows x 13 columns]

# %%
c.execute('SELECT * from orderdetails GROUP BY productCode')
df = pd.DataFrame(c.fetchall())
df.columns = [x[0] for x in c.description]
df
# Out:
#     orderNumber productCode quantityOrdered priceEach orderLineNumber
# 0         10417    S10_1678              66     79.43               2
# 1         10424    S10_1949              50    201.44               6
# 2         10417    S10_2016              45    116.56               5
# 3         10417    S10_4698              56    162.67               4
# 4         10414    S10_4757              49    114.24               3
# 5         10425    S10_4962              38    131.49              12
# 6         10419    S12_1099              12    182.90              13
# 7         10413    S12_1108              36    201.57               2
# 8         10424    S12_1666              49    121.64               3
# 9         10417    S12_2823              21    144.60               1
# 10        10413    S12_3148              47    145.04               3
# 11        10419    S12_3380              10    111.57              11
# 12        10413    S12_3891              22    173.02               1
# 13        10419    S12_3990              34     64.64              14
# 14        10425    S12_4473              33     95.99               4
# 15        10419    S12_4675              32     99.04              10
# 16        10424    S18_1097              54    108.50               5
# 17        10419    S18_1129              38    117.48               5
# 18        10422    S18_1342              51     91.44               2
# 19        10422    S18_1367              25     47.44               1
# 20        10419    S18_1589              37    100.80               1
# 21        10416    S18_1662              24    129.31              14
# 22        10420    S18_1749              37    153.00               5
# 23        10419    S18_1889              39     67.76               9
# 24        10419    S18_1984              34    133.72               4
# 25        10425    S18_2238              28    147.36               3
# 26        10420    S18_2248              36     52.06               4
# 27        10425    S18_2319              38    117.82               7
# 28        10420    S18_2325              45    116.96               2
# 29        10425    S18_2432              19     48.62              10
# ..          ...         ...             ...       ...             ...
# 79        10412    S24_4048              31    108.82               1
# 80        10423    S24_4258              28     78.89               4
# 81        10416    S24_4278              48     70.28               5
# 82        10418    S24_4620              10     66.29               3
# 83        10425    S32_1268              41     83.79              11
# 84        10416    S32_1374              45     86.90               2
# 85        10418    S32_2206              43     36.61               6
# 86        10425    S32_2509              11     50.32               6
# 87        10413    S32_3207              24     56.55               6
# 88        10424    S32_3522              44     54.94               2
# 89        10416    S32_4289              26     68.10               7
# 90        10418    S32_4485              50    100.01               9
# 91        10416    S50_1341              37     39.71               8
# 92        10425    S50_1392              18     94.92               2
# 93        10413    S50_1514              51     53.31               4
# 94        10418    S50_4713              40     72.41               7
# 95        10414   S700_1138              37     62.00               6
# 96        10416   S700_1691              23     88.60               9
# 97        10414   S700_1938              34     74.48              13
# 98        10415   S700_2047              32     73.32               4
# 99        10416   S700_2466              22     84.76              11
# 100       10414   S700_2610              31     61.44               4
# 101       10424   S700_2824              46     85.98               1
# 102       10416   S700_2834              41     98.48               3
# 103       10416   S700_3167              39     65.60              10
# 104       10414   S700_3505              28     84.14               7
# 105       10414   S700_3962              40     84.41               8
# 106       10416   S700_4002              43     63.67              12
# 107       10415    S72_1253              42     43.20               3
# 108       10414    S72_3212              47     54.60               9
#
# [109 rows x 5 columns]

# %% [markdown]
# ## Select the Product Name and the  Total Number of People Who Have Ordered Each Product
#
# Sort the results in descending order.

# %%
#Your code here

# %% [markdown]
# ## Select the Employee Number, Office Code, City (of the office), and Name (First and Last) of those Employees who Sold Products that Have Been Ordered by Less Then 20 people.
#
# This problem is a bit tougher. To start, think about how you might break the problem up. Be sure that your results only list each employee once.

# %%
#Your code here

c.execute("""SELECT employeeNumber, officeCode, offices.city,
            lastName, firstName FROM 
            (SELECT employeeNumber FROM employees
            JOIN customers ON employees.employeeNumber = customers.salesRepEmployeeNumber
            
            
            
            
            
            """)

# %% [markdown]
# ## Select the Employee Number, Name (First and Last) and Number of Customers of Employees Who's Customers Have an Average Credit Limit of Over 15K

# %%
#Your code here



c.execute("""SELECT employeeNumber, lastName, firstName 
                """)

# %% [markdown]
# ## Summary
#
# In this lesson, you got to practice some more complex SQL queries, some of which required subqueries. There's still plenty more SQL to be had though; hope you've been enjoying some of these puzzles!
