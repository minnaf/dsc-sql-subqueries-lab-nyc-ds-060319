# %% [markdown]
# # SQL Subqueries - Lab
#
# ## Introduction
#
# Now that you've seen how subqueries work, it's time to get some practice writing them! Not all of the queries will require subqueries, but all will be a bit more complex and require some thought and review about aggregates, grouping, ordering, filtering, joins and subqueries. Good luck!
#
# ## Objectives
#
# You will be able to:
#
# * Write subqueries to decompose complex queries
#
# ## CRM Database Schema
#
# Once again, here's the schema for the CRM database you'll continue to practice with.
#
# <img src="images/Database-Schema.png" width="600">
#
# ## Connect to the Database
#
# As usual, start by importing the necessary packages and connecting to the database **data.sqlite**.

# %%
#Your code here; import the necessary packages
import pandas as pd 
import sqlite3

conn = sqlite3.connect("data.sqlite")
c = conn.cursor()

# %%
#Your code here; create the connection and cursor

# %% [markdown]
# ## Select the Average Number of Orders on a Product by Product Basis

# %%
#Your code here; use a subquery. No join will be necessary.


c.execute("""select AVG(numOrders)
                    from (select productCode,
                                 count(distinct orderNumber) as numOrders
                                 from products
                                 join orderdetails
                                 using(productCode)
                                 group by 1
                         );
          """
         )

df = pd.DataFrame(c.fetchall())
df.columns = [x[0] for x in c.description]
df
# Out:
#    AVG(numOrders)
# 0       27.486239

# %% [markdown]
# ## Write an Equivalent Query using a Subquery
#
# ```SQL
# select customerNumber,
#        contactLastName,
#        contactFirstName
#        from customers
#        join orders
#        using(customerNumber)
#        where orderDate = '2003-01-31';
# ```

# %%
#Your code here; use a subquery. No join will be necessary.

# %% [markdown]
# ## Select the Total Number of Orders for Each Product Name
#
# Sort the results by the total number of items sold for that product.

# %%
#Your code here
c.execute(""" SELECT productName, SUM(quantityOrdered) 
          FROM products 
          JOIN orderdetails USING(productCode) 
          GROUP BY productCode


""")






df = pd.DataFrame(c.fetchall())
df.columns = [x[0] for x in c.description]
df

454
# Out:
#                                      productName  SUM(quantityOrdered)
# 0          1969 Harley Davidson Ultimate Chopper                  1057
# 1                       1952 Alpine Renault 1300                   961
# 2                          1996 Moto Guzzi 1100i                   999
# 3           2003 Harley-Davidson Eagle Drag Bike                   985
# 4                            1972 Alfa Romeo GTA                  1030
# 5                         1962 LanciaA Delta 16V                   932
# 6                              1968 Ford Mustang                   933
# 7                              2001 Ferrari Enzo                  1019
# 8                                 1958 Setra Bus                   972
# 9                               2002 Suzuki XREO                  1028
# 10                            1969 Corvair Monza                   963
# 11                            1968 Dodge Charger                   925
# 12                              1969 Ford Falcon                   965
# 13                       1970 Plymouth Hemi Cuda                   900
# 14                             1957 Chevy Pickup                  1056
# 15                            1969 Dodge Charger                   992
# 16                        1940 Ford Pickup Truck                   999
# 17                               1993 Mazda RX-7                   947
# 18                          1937 Lincoln Berline                  1111
# 19      1936 Mercedes-Benz 500K Special Roadster                   960
# 20                         1965 Aston Martin DB5                   914
# 21                   1980s Black Hawk Helicopter                  1040
# 22                      1917 Grand Touring Sedan                   918
# 23                   1948 Porsche 356-A Roadster                   972
# 24                              1995 Honda Civic                   917
# 25                1998 Chrysler Plymouth Prowler                   986
# 26                            1911 Ford Town Car                   832
# 27                        1964 Mercedes Tour Bus                  1053
# 28                     1932 Model A Ford J-Coupe                   957
# 29                         1926 Ford Fire Engine                   998
# ..                                           ...                   ...
# 79             1992 Porsche Cayenne Turbo Silver                   867
# 80                         1936 Chrysler Airflow                   983
# 81                       1900s Vintage Tri-Plane                  1009
# 82                         1961 Chevrolet Impala                   941
# 83                   1980’s GM Manhattan Express                   911
# 84                              1997 BMW F650 ST                  1014
# 85                             1982 Ducati 996 R                   906
# 86                   1954 Greyhound Scenicruiser                   955
# 87        1950's Chicago Surface Lines Streetcar                   934
# 88   1996 Peterbilt 379 Stake Bed with Outrigger                   988
# 89                      1928 Ford Phaeton Deluxe                   972
# 90                     1974 Ducati 350 Mk3 Desmo                   898
# 91                  1930 Buick Marquette Phaeton                  1074
# 92              Diamond T620 Semi-Skirted Tanker                   979
# 93                1962 City of Detroit Streetcar                   966
# 94                            2002 Yamaha YZR M1                   992
# 95                         The Schooner Bluenose                   934
# 96                   American Airlines: B767-300                   894
# 97                                 The Mayflower                   898
# 98                                    HMS Bounty                   897
# 99                America West Airlines B757-200                   984
# 100                    The USS Constitution Ship                  1020
# 101                              1982 Camaro Z28                   997
# 102                                ATA: B757-300                   973
# 103                           F/A 18 Hornet 1/72                  1047
# 104                                  The Titanic                   952
# 105                               The Queen Mary                   896
# 106                    American Airlines: MD-11S                  1085
# 107                             Boeing X-32A JSF                   960
# 108                                   Pont Yacht                   958
#
# [109 rows x 2 columns]

# %%
c.execute('SELECT * from orderdetails GROUP BY productCode')
df = pd.DataFrame(c.fetchall())
df.columns = [x[0] for x in c.description]
df
# Out:
#     orderNumber productCode quantityOrdered priceEach orderLineNumber
# 0         10417    S10_1678              66     79.43               2
# 1         10424    S10_1949              50    201.44               6
# 2         10417    S10_2016              45    116.56               5
# 3         10417    S10_4698              56    162.67               4
# 4         10414    S10_4757              49    114.24               3
# 5         10425    S10_4962              38    131.49              12
# 6         10419    S12_1099              12    182.90              13
# 7         10413    S12_1108              36    201.57               2
# 8         10424    S12_1666              49    121.64               3
# 9         10417    S12_2823              21    144.60               1
# 10        10413    S12_3148              47    145.04               3
# 11        10419    S12_3380              10    111.57              11
# 12        10413    S12_3891              22    173.02               1
# 13        10419    S12_3990              34     64.64              14
# 14        10425    S12_4473              33     95.99               4
# 15        10419    S12_4675              32     99.04              10
# 16        10424    S18_1097              54    108.50               5
# 17        10419    S18_1129              38    117.48               5
# 18        10422    S18_1342              51     91.44               2
# 19        10422    S18_1367              25     47.44               1
# 20        10419    S18_1589              37    100.80               1
# 21        10416    S18_1662              24    129.31              14
# 22        10420    S18_1749              37    153.00               5
# 23        10419    S18_1889              39     67.76               9
# 24        10419    S18_1984              34    133.72               4
# 25        10425    S18_2238              28    147.36               3
# 26        10420    S18_2248              36     52.06               4
# 27        10425    S18_2319              38    117.82               7
# 28        10420    S18_2325              45    116.96               2
# 29        10425    S18_2432              19     48.62              10
# ..          ...         ...             ...       ...             ...
# 79        10412    S24_4048              31    108.82               1
# 80        10423    S24_4258              28     78.89               4
# 81        10416    S24_4278              48     70.28               5
# 82        10418    S24_4620              10     66.29               3
# 83        10425    S32_1268              41     83.79              11
# 84        10416    S32_1374              45     86.90               2
# 85        10418    S32_2206              43     36.61               6
# 86        10425    S32_2509              11     50.32               6
# 87        10413    S32_3207              24     56.55               6
# 88        10424    S32_3522              44     54.94               2
# 89        10416    S32_4289              26     68.10               7
# 90        10418    S32_4485              50    100.01               9
# 91        10416    S50_1341              37     39.71               8
# 92        10425    S50_1392              18     94.92               2
# 93        10413    S50_1514              51     53.31               4
# 94        10418    S50_4713              40     72.41               7
# 95        10414   S700_1138              37     62.00               6
# 96        10416   S700_1691              23     88.60               9
# 97        10414   S700_1938              34     74.48              13
# 98        10415   S700_2047              32     73.32               4
# 99        10416   S700_2466              22     84.76              11
# 100       10414   S700_2610              31     61.44               4
# 101       10424   S700_2824              46     85.98               1
# 102       10416   S700_2834              41     98.48               3
# 103       10416   S700_3167              39     65.60              10
# 104       10414   S700_3505              28     84.14               7
# 105       10414   S700_3962              40     84.41               8
# 106       10416   S700_4002              43     63.67              12
# 107       10415    S72_1253              42     43.20               3
# 108       10414    S72_3212              47     54.60               9
#
# [109 rows x 5 columns]

# %% [markdown]
# ## Select the Product Name and the  Total Number of People Who Have Ordered Each Product
#
# Sort the results in descending order.

# %%
#Your code here

# %% [markdown]
# ## Select the Employee Number, Office Code, City (of the office), and Name (First and Last) of those Employees who Sold Products that Have Been Ordered by Less Then 20 people.
#
# This problem is a bit tougher. To start, think about how you might break the problem up. Be sure that your results only list each employee once.

# %%
#Your code here

c.execute("""SELECT employeeNumber, officeCode, offices.city,
            lastName, firstName FROM 
            (SELECT employeeNumber FROM employees
            JOIN customers ON employees.employeeNumber = customers.salesRepEmployeeNumber
            
            
            
            
            
            """)

# %% [markdown]
# ## Select the Employee Number, Name (First and Last) and Number of Customers of Employees Who's Customers Have an Average Credit Limit of Over 15K

# %%
#Your code here



c.execute("""SELECT employeeNumber, lastName, firstName 
                """)

# %% [markdown]
# ## Summary
#
# In this lesson, you got to practice some more complex SQL queries, some of which required subqueries. There's still plenty more SQL to be had though; hope you've been enjoying some of these puzzles!
