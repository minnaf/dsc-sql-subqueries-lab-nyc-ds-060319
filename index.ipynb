# %% [markdown]
# # SQL Subqueries - Lab
#
# ## Introduction
#
# Now that you've seen how subqueries work, it's time to get some practice writing them! Not all of the queries will require subqueries, but all will be a bit more complex and require some thought and review about aggregates, grouping, ordering, filtering, joins and subqueries. Good luck!
#
# ## Objectives
#
# You will be able to:
#
# * Write subqueries to decompose complex queries
#
# ## CRM Database Schema
#
# Once again, here's the schema for the CRM database you'll continue to practice with.
#
# <img src="images/Database-Schema.png" width="600">
#
# ## Connect to the Database
#
# As usual, start by importing the necessary packages and connecting to the database **data.sqlite**.

# %%
#Your code here; import the necessary packages
import pandas as pd 
import sqlite3

conn = sqlite3.connect("data.sqlite")
c = conn.cursor()

# %%
#Your code here; create the connection and cursor

# %% [markdown]
# ## Select the Average Number of Orders on a Product by Product Basis

# %%
#Your code here; use a subquery. No join will be necessary.


c.execute("""select AVG(numOrders)
                    from (select productCode,
                                 count(distinct orderNumber) as numOrders
                                 from products
                                 join orderdetails
                                 using(productCode)
                                 group by 1
                         );
          """
         )

df = pd.DataFrame(c.fetchall())
df.columns = [x[0] for x in c.description]
df
# Out:
#    AVG(numOrders)
# 0       27.486239

# %% [markdown]
# ## Write an Equivalent Query using a Subquery
#
# ```SQL
# select customerNumber,
#        contactLastName,
#        contactFirstName
#        from customers
#        join orders
#        using(customerNumber)
#        where orderDate = '2003-01-31';
# ```

# %%
#Your code here; use a subquery. No join will be necessary.

# %% [markdown]
# ## Select the Total Number of Orders for Each Product Name
#
# Sort the results by the total number of items sold for that product.

# %%
#Your code here
c.execute(""" SELECT * FROM products 
          JOIN orderdetails USING(productCode) 
          GROUP BY productCode


""")






df = pd.DataFrame(c.fetchall())
df.columns = [x[0] for x in c.description]
df
# Out:
#     productCode                                  productName  \
# 0      S10_1678        1969 Harley Davidson Ultimate Chopper
# 1      S10_1949                     1952 Alpine Renault 1300
# 2      S10_2016                        1996 Moto Guzzi 1100i
# 3      S10_4698         2003 Harley-Davidson Eagle Drag Bike
# 4      S10_4757                          1972 Alfa Romeo GTA
# 5      S10_4962                       1962 LanciaA Delta 16V
# 6      S12_1099                            1968 Ford Mustang
# 7      S12_1108                            2001 Ferrari Enzo
# 8      S12_1666                               1958 Setra Bus
# 9      S12_2823                             2002 Suzuki XREO
# 10     S12_3148                           1969 Corvair Monza
# 11     S12_3380                           1968 Dodge Charger
# 12     S12_3891                             1969 Ford Falcon
# 13     S12_3990                      1970 Plymouth Hemi Cuda
# 14     S12_4473                            1957 Chevy Pickup
# 15     S12_4675                           1969 Dodge Charger
# 16     S18_1097                       1940 Ford Pickup Truck
# 17     S18_1129                              1993 Mazda RX-7
# 18     S18_1342                         1937 Lincoln Berline
# 19     S18_1367     1936 Mercedes-Benz 500K Special Roadster
# 20     S18_1589                        1965 Aston Martin DB5
# 21     S18_1662                  1980s Black Hawk Helicopter
# 22     S18_1749                     1917 Grand Touring Sedan
# 23     S18_1889                  1948 Porsche 356-A Roadster
# 24     S18_1984                             1995 Honda Civic
# 25     S18_2238               1998 Chrysler Plymouth Prowler
# 26     S18_2248                           1911 Ford Town Car
# 27     S18_2319                       1964 Mercedes Tour Bus
# 28     S18_2325                    1932 Model A Ford J-Coupe
# 29     S18_2432                        1926 Ford Fire Engine
# ..          ...                                          ...
# 79     S24_4048            1992 Porsche Cayenne Turbo Silver
# 80     S24_4258                        1936 Chrysler Airflow
# 81     S24_4278                      1900s Vintage Tri-Plane
# 82     S24_4620                        1961 Chevrolet Impala
# 83     S32_1268                  1980’s GM Manhattan Express
# 84     S32_1374                             1997 BMW F650 ST
# 85     S32_2206                            1982 Ducati 996 R
# 86     S32_2509                  1954 Greyhound Scenicruiser
# 87     S32_3207       1950's Chicago Surface Lines Streetcar
# 88     S32_3522  1996 Peterbilt 379 Stake Bed with Outrigger
# 89     S32_4289                     1928 Ford Phaeton Deluxe
# 90     S32_4485                    1974 Ducati 350 Mk3 Desmo
# 91     S50_1341                 1930 Buick Marquette Phaeton
# 92     S50_1392             Diamond T620 Semi-Skirted Tanker
# 93     S50_1514               1962 City of Detroit Streetcar
# 94     S50_4713                           2002 Yamaha YZR M1
# 95    S700_1138                        The Schooner Bluenose
# 96    S700_1691                  American Airlines: B767-300
# 97    S700_1938                                The Mayflower
# 98    S700_2047                                   HMS Bounty
# 99    S700_2466               America West Airlines B757-200
# 100   S700_2610                    The USS Constitution Ship
# 101   S700_2824                              1982 Camaro Z28
# 102   S700_2834                                ATA: B757-300
# 103   S700_3167                           F/A 18 Hornet 1/72
# 104   S700_3505                                  The Titanic
# 105   S700_3962                               The Queen Mary
# 106   S700_4002                    American Airlines: MD-11S
# 107    S72_1253                             Boeing X-32A JSF
# 108    S72_3212                                   Pont Yacht
#
#           productLine productScale              productVendor  \
# 0         Motorcycles         1:10            Min Lin Diecast
# 1        Classic Cars         1:10    Classic Metal Creations
# 2         Motorcycles         1:10   Highway 66 Mini Classics
# 3         Motorcycles         1:10          Red Start Diecast
# 4        Classic Cars         1:10    Motor City Art Classics
# 5        Classic Cars         1:10        Second Gear Diecast
# 6        Classic Cars         1:12      Autoart Studio Design
# 7        Classic Cars         1:12        Second Gear Diecast
# 8    Trucks and Buses         1:12  Welly Diecast Productions
# 9         Motorcycles         1:12       Unimax Art Galleries
# 10       Classic Cars         1:18  Welly Diecast Productions
# 11       Classic Cars         1:12  Welly Diecast Productions
# 12       Classic Cars         1:12        Second Gear Diecast
# 13       Classic Cars         1:12        Studio M Art Models
# 14   Trucks and Buses         1:12              Exoto Designs
# 15       Classic Cars         1:12  Welly Diecast Productions
# 16   Trucks and Buses         1:18        Studio M Art Models
# 17       Classic Cars         1:18   Highway 66 Mini Classics
# 18       Vintage Cars         1:18    Motor City Art Classics
# 19       Vintage Cars         1:18        Studio M Art Models
# 20       Classic Cars         1:18    Classic Metal Creations
# 21             Planes         1:18          Red Start Diecast
# 22       Vintage Cars         1:18  Welly Diecast Productions
# 23       Classic Cars         1:18       Gearbox Collectibles
# 24       Classic Cars         1:18            Min Lin Diecast
# 25       Classic Cars         1:18       Gearbox Collectibles
# 26       Vintage Cars         1:18    Motor City Art Classics
# 27   Trucks and Buses         1:18       Unimax Art Galleries
# 28       Vintage Cars         1:18      Autoart Studio Design
# 29   Trucks and Buses         1:18   Carousel DieCast Legends
# ..                ...          ...                        ...
# 79       Classic Cars         1:24              Exoto Designs
# 80       Vintage Cars         1:24        Second Gear Diecast
# 81             Planes         1:24       Unimax Art Galleries
# 82       Classic Cars         1:18    Classic Metal Creations
# 83   Trucks and Buses         1:32    Motor City Art Classics
# 84        Motorcycles         1:32              Exoto Designs
# 85        Motorcycles         1:32       Gearbox Collectibles
# 86   Trucks and Buses         1:32    Classic Metal Creations
# 87             Trains         1:32       Gearbox Collectibles
# 88   Trucks and Buses         1:32          Red Start Diecast
# 89       Vintage Cars         1:32   Highway 66 Mini Classics
# 90        Motorcycles         1:32        Second Gear Diecast
# 91       Vintage Cars         1:50        Studio M Art Models
# 92   Trucks and Buses         1:50   Highway 66 Mini Classics
# 93             Trains         1:50    Classic Metal Creations
# 94        Motorcycles         1:50      Autoart Studio Design
# 95              Ships        1:700      Autoart Studio Design
# 96             Planes        1:700            Min Lin Diecast
# 97              Ships        1:700        Studio M Art Models
# 98              Ships        1:700       Unimax Art Galleries
# 99             Planes        1:700    Motor City Art Classics
# 100             Ships        1:700          Red Start Diecast
# 101      Classic Cars         1:18   Carousel DieCast Legends
# 102            Planes        1:700   Highway 66 Mini Classics
# 103            Planes         1:72    Motor City Art Classics
# 104             Ships        1:700   Carousel DieCast Legends
# 105             Ships        1:700  Welly Diecast Productions
# 106            Planes        1:700        Second Gear Diecast
# 107            Planes         1:72    Motor City Art Classics
# 108             Ships         1:72       Unimax Art Galleries
#
#                                     productDescription quantityInStock  \
# 0    This replica features working kickstand, front...            7933
# 1    Turnable front wheels; steering function; deta...            7305
# 2    Official Moto Guzzi logos and insignias, saddl...            6625
# 3    Model features, official Harley Davidson logos...            5582
# 4    Features include: Turnable front wheels; steer...            3252
# 5    Features include: Turnable front wheels; steer...            6791
# 6    Hood, doors and trunk all open to reveal highl...              68
# 7    Turnable front wheels; steering function; deta...            3619
# 8    Model features 30 windows, skylights & glare r...            1579
# 9    Official logos and insignias, saddle bags loca...            9997
# 10   1:18 scale die-cast about 10" long doors open,...            6906
# 11   1:12 scale model of a 1968 Dodge Charger. Hood...            9123
# 12   Turnable front wheels; steering function; deta...            1049
# 13   Very detailed 1970 Plymouth Cuda model in 1:12...            5663
# 14   1:12 scale die-cast about 20" long Hood opens,...            6125
# 15   Detailed model of the 1969 Dodge Charger. This...            7323
# 16   This model features soft rubber tires, working...            2613
# 17   This model features, opening hood, opening doo...            3975
# 18   Features opening engine cover, doors, trunk, a...            8693
# 19   This 1:18 scale replica is constructed of heav...            8635
# 20   Die-cast model of the silver 1965 Aston Martin...            9042
# 21   1:18 scale replica of actual Army's UH-60L BLA...            5330
# 22   This 1:18 scale replica of the 1917 Grand Tour...            2724
# 23   This precision die-cast replica features openi...            8826
# 24   This model features, opening hood, opening doo...            9772
# 25   Turnable front wheels; steering function; deta...            4724
# 26   Features opening hood, opening doors, opening ...             540
# 27   Exact replica. 100+ parts. working steering sy...            8258
# 28   This model features grille-mounted chrome horn...            9354
# 29   Gleaming red handsome appearance. Everything i...            2018
# ..                                                 ...             ...
# 79   This replica features opening doors, superb de...            6582
# 80   Features opening trunk,  working steering syst...            4710
# 81   Hand crafted diecast-like metal Triplane is Re...            2756
# 82   This 1:18 scale precision die-cast reproductio...            7869
# 83   This 1980’s era new look Manhattan express is ...            5099
# 84   Features official die-struck logos and baked e...             178
# 85   Features rotating wheels , working kick stand....            9241
# 86   Model features bi-level seating, 50 windows, s...            2874
# 87   This streetcar is a joy to see. It has 80 sepa...            8601
# 88   This model features, opening doors, detailed e...             814
# 89   This model features grille-mounted chrome horn...             136
# 90   This model features two-tone paint with chrome...            3341
# 91    Features opening trunk,  working steering system            7062
# 92   This limited edition model is licensed and per...            1016
# 93   This streetcar is a joy to see. It has 99 sepa...            1645
# 94   Features rotating wheels , working kick stand....             600
# 95   All wood with canvas sails. Measures 31 1/2 in...            1897
# 96   Exact replia with official logos and insignias...            5841
# 97   Measures 31 1/2 inches Long x 25 1/2 inches Hi...             737
# 98   Measures 30 inches Long x 27 1/2 inches High x...            3501
# 99   Official logos and insignias. Working steering...            9653
# 100  All wood with canvas sails. Measures 31 1/2" L...            7083
# 101  Features include opening and closing doors. Co...            6934
# 102  Exact replia with official logos and insignias...            7106
# 103  10" Wingspan with retractable landing gears.Co...             551
# 104  Completed model measures 19 1/2 inches long, 9...            1956
# 105  Exact replica. Wood and Metal. Many extras inc...            5088
# 106  Polished finish. Exact replia with official lo...            8820
# 107  10" Wingspan with retractable landing gears.Co...            4857
# 108  Measures 38 inches Long x 33 3/4 inches High. ...             414
#
#     buyPrice    MSRP orderNumber quantityOrdered priceEach orderLineNumber
# 0      48.81   95.70       10417              66     79.43               2
# 1      98.58  214.30       10424              50    201.44               6
# 2      68.99  118.94       10417              45    116.56               5
# 3      91.02  193.66       10417              56    162.67               4
# 4      85.68  136.00       10414              49    114.24               3
# 5     103.42  147.74       10425              38    131.49              12
# 6      95.34  194.57       10419              12    182.90              13
# 7      95.59  207.80       10413              36    201.57               2
# 8      77.90  136.67       10424              49    121.64               3
# 9      66.27  150.62       10417              21    144.60               1
# 10     89.14  151.08       10413              47    145.04               3
# 11     75.16  117.44       10419              10    111.57              11
# 12     83.05  173.02       10413              22    173.02               1
# 13     31.92   79.80       10419              34     64.64              14
# 14     55.70  118.50       10425              33     95.99               4
# 15     58.73  115.16       10419              32     99.04              10
# 16     58.33  116.67       10424              54    108.50               5
# 17     83.51  141.54       10419              38    117.48               5
# 18     60.62  102.74       10422              51     91.44               2
# 19     24.26   53.91       10422              25     47.44               1
# 20     65.96  124.44       10419              37    100.80               1
# 21     77.27  157.69       10416              24    129.31              14
# 22     86.70  170.00       10420              37    153.00               5
# 23     53.90   77.00       10419              39     67.76               9
# 24     93.89  142.25       10419              34    133.72               4
# 25    101.51  163.73       10425              28    147.36               3
# 26     33.30   60.54       10420              36     52.06               4
# 27     74.86  122.73       10425              38    117.82               7
# 28     58.48  127.13       10420              45    116.96               2
# 29     24.92   60.77       10425              19     48.62              10
# ..       ...     ...         ...             ...       ...             ...
# 79     69.78  118.28       10412              31    108.82               1
# 80     57.46   97.39       10423              28     78.89               4
# 81     36.23   72.45       10416              48     70.28               5
# 82     32.33   80.84       10418              10     66.29               3
# 83     53.93   96.31       10425              41     83.79              11
# 84     66.92   99.89       10416              45     86.90               2
# 85     24.14   40.23       10418              43     36.61               6
# 86     25.98   54.11       10425              11     50.32               6
# 87     26.72   62.14       10413              24     56.55               6
# 88     33.61   64.64       10424              44     54.94               2
# 89     33.02   68.79       10416              26     68.10               7
# 90     56.13  102.05       10418              50    100.01               9
# 91     27.06   43.64       10416              37     39.71               8
# 92     68.29  115.75       10425              18     94.92               2
# 93     37.49   58.58       10413              51     53.31               4
# 94     34.17   81.36       10418              40     72.41               7
# 95     34.00   66.67       10414              37     62.00               6
# 96     51.15   91.34       10416              23     88.60               9
# 97     43.30   86.61       10414              34     74.48              13
# 98     39.83   90.52       10415              32     73.32               4
# 99     68.80   99.72       10416              22     84.76              11
# 100    33.97   72.28       10414              31     61.44               4
# 101    46.53  101.15       10424              46     85.98               1
# 102    59.33  118.65       10416              41     98.48               3
# 103    54.40   80.00       10416              39     65.60              10
# 104    51.09  100.17       10414              28     84.14               7
# 105    53.63   99.31       10414              40     84.41               8
# 106    36.27   74.03       10416              43     63.67              12
# 107    32.77   49.66       10415              42     43.20               3
# 108    33.30   54.60       10414              47     54.60               9
#
# [109 rows x 13 columns]

# %%
c.execute('SELECT * from orderdetails GROUP BY productCode')
df = pd.DataFrame(c.fetchall())
df.columns = [x[0] for x in c.description]
df
# Out:
#     orderNumber productCode quantityOrdered priceEach orderLineNumber
# 0         10417    S10_1678              66     79.43               2
# 1         10424    S10_1949              50    201.44               6
# 2         10417    S10_2016              45    116.56               5
# 3         10417    S10_4698              56    162.67               4
# 4         10414    S10_4757              49    114.24               3
# 5         10425    S10_4962              38    131.49              12
# 6         10419    S12_1099              12    182.90              13
# 7         10413    S12_1108              36    201.57               2
# 8         10424    S12_1666              49    121.64               3
# 9         10417    S12_2823              21    144.60               1
# 10        10413    S12_3148              47    145.04               3
# 11        10419    S12_3380              10    111.57              11
# 12        10413    S12_3891              22    173.02               1
# 13        10419    S12_3990              34     64.64              14
# 14        10425    S12_4473              33     95.99               4
# 15        10419    S12_4675              32     99.04              10
# 16        10424    S18_1097              54    108.50               5
# 17        10419    S18_1129              38    117.48               5
# 18        10422    S18_1342              51     91.44               2
# 19        10422    S18_1367              25     47.44               1
# 20        10419    S18_1589              37    100.80               1
# 21        10416    S18_1662              24    129.31              14
# 22        10420    S18_1749              37    153.00               5
# 23        10419    S18_1889              39     67.76               9
# 24        10419    S18_1984              34    133.72               4
# 25        10425    S18_2238              28    147.36               3
# 26        10420    S18_2248              36     52.06               4
# 27        10425    S18_2319              38    117.82               7
# 28        10420    S18_2325              45    116.96               2
# 29        10425    S18_2432              19     48.62              10
# ..          ...         ...             ...       ...             ...
# 79        10412    S24_4048              31    108.82               1
# 80        10423    S24_4258              28     78.89               4
# 81        10416    S24_4278              48     70.28               5
# 82        10418    S24_4620              10     66.29               3
# 83        10425    S32_1268              41     83.79              11
# 84        10416    S32_1374              45     86.90               2
# 85        10418    S32_2206              43     36.61               6
# 86        10425    S32_2509              11     50.32               6
# 87        10413    S32_3207              24     56.55               6
# 88        10424    S32_3522              44     54.94               2
# 89        10416    S32_4289              26     68.10               7
# 90        10418    S32_4485              50    100.01               9
# 91        10416    S50_1341              37     39.71               8
# 92        10425    S50_1392              18     94.92               2
# 93        10413    S50_1514              51     53.31               4
# 94        10418    S50_4713              40     72.41               7
# 95        10414   S700_1138              37     62.00               6
# 96        10416   S700_1691              23     88.60               9
# 97        10414   S700_1938              34     74.48              13
# 98        10415   S700_2047              32     73.32               4
# 99        10416   S700_2466              22     84.76              11
# 100       10414   S700_2610              31     61.44               4
# 101       10424   S700_2824              46     85.98               1
# 102       10416   S700_2834              41     98.48               3
# 103       10416   S700_3167              39     65.60              10
# 104       10414   S700_3505              28     84.14               7
# 105       10414   S700_3962              40     84.41               8
# 106       10416   S700_4002              43     63.67              12
# 107       10415    S72_1253              42     43.20               3
# 108       10414    S72_3212              47     54.60               9
#
# [109 rows x 5 columns]

# %% [markdown]
# ## Select the Product Name and the  Total Number of People Who Have Ordered Each Product
#
# Sort the results in descending order.

# %%
#Your code here

# %% [markdown]
# ## Select the Employee Number, Office Code, City (of the office), and Name (First and Last) of those Employees who Sold Products that Have Been Ordered by Less Then 20 people.
#
# This problem is a bit tougher. To start, think about how you might break the problem up. Be sure that your results only list each employee once.

# %%
#Your code here

c.execute("""SELECT employeeNumber, officeCode, offices.city,
            lastName, firstName FROM 
            (SELECT employeeNumber FROM employees
            JOIN customers ON employees.employeeNumber = customers.salesRepEmployeeNumber
            
            
            
            
            
            """)

# %% [markdown]
# ## Select the Employee Number, Name (First and Last) and Number of Customers of Employees Who's Customers Have an Average Credit Limit of Over 15K

# %%
#Your code here



c.execute("""SELECT employeeNumber, lastName, firstName 
                """)

# %% [markdown]
# ## Summary
#
# In this lesson, you got to practice some more complex SQL queries, some of which required subqueries. There's still plenty more SQL to be had though; hope you've been enjoying some of these puzzles!
