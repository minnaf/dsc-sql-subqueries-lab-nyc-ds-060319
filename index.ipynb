# %% [markdown]
# # SQL Subqueries - Lab
#
# ## Introduction
#
# Now that you've seen how subqueries work, it's time to get some practice writing them! Not all of the queries will require subqueries, but all will be a bit more complex and require some thought and review about aggregates, grouping, ordering, filtering, joins and subqueries. Good luck!
#
# ## Objectives
#
# You will be able to:
#
# * Write subqueries to decompose complex queries
#
# ## CRM Database Schema
#
# Once again, here's the schema for the CRM database you'll continue to practice with.
#
# <img src="images/Database-Schema.png" width="600">
#
# ## Connect to the Database
#
# As usual, start by importing the necessary packages and connecting to the database **data.sqlite**.

# %%
#Your code here; import the necessary packages
import pandas as pd 
import sqlite3

conn = sqlite3.connect("data.sqlite")
c = conn.cursor()

# %%
#Your code here; create the connection and cursor

# %% [markdown]
# ## Select the Average Number of Orders on a Product by Product Basis

# %%
#Your code here; use a subquery. No join will be necessary.


c.execute("""select AVG(numOrders)
                    from (select productCode,
                                 count(distinct orderNumber) as numOrders
                                 from products
                                 join orderdetails
                                 using(productCode)
                                 group by 1
                         );
          """
         )

df = pd.DataFrame(c.fetchall())
df.columns = [x[0] for x in c.description]
df
# Out:
#    AVG(numOrders)
# 0       27.486239

# %% [markdown]
# ## Write an Equivalent Query using a Subquery
#
# ```SQL
# select customerNumber,
#        contactLastName,
#        contactFirstName
#        from customers
#        join orders
#        using(customerNumber)
#        where orderDate = '2003-01-31';
# ```

# %%
#Your code here; use a subquery. No join will be necessary.

# %% [markdown]
# ## Select the Total Number of Orders for Each Product Name
#
# Sort the results by the total number of items sold for that product.

# %%
#Your code here
c.execute(""" SELECT productName, quantityOrdered FROM products 
          JOIN orderdetails USING(productCode) GROUP BY productCode


""")






df = pd.DataFrame(c.fetchall())
df.columns = [x[0] for x in c.description]
df
# Out:
#                                 productName quantityOrdered
# 0     1969 Harley Davidson Ultimate Chopper              20
# 1     1969 Harley Davidson Ultimate Chopper              21
# 2     1969 Harley Davidson Ultimate Chopper              22
# 3     1969 Harley Davidson Ultimate Chopper              23
# 4     1969 Harley Davidson Ultimate Chopper              23
# 5     1969 Harley Davidson Ultimate Chopper              24
# 6     1969 Harley Davidson Ultimate Chopper              29
# 7     1969 Harley Davidson Ultimate Chopper              30
# 8     1969 Harley Davidson Ultimate Chopper              34
# 9     1969 Harley Davidson Ultimate Chopper              34
# 10    1969 Harley Davidson Ultimate Chopper              36
# 11    1969 Harley Davidson Ultimate Chopper              36
# 12    1969 Harley Davidson Ultimate Chopper              37
# 13    1969 Harley Davidson Ultimate Chopper              40
# 14    1969 Harley Davidson Ultimate Chopper              41
# 15    1969 Harley Davidson Ultimate Chopper              41
# 16    1969 Harley Davidson Ultimate Chopper              41
# 17    1969 Harley Davidson Ultimate Chopper              41
# 18    1969 Harley Davidson Ultimate Chopper              42
# 19    1969 Harley Davidson Ultimate Chopper              42
# 20    1969 Harley Davidson Ultimate Chopper              42
# 21    1969 Harley Davidson Ultimate Chopper              45
# 22    1969 Harley Davidson Ultimate Chopper              45
# 23    1969 Harley Davidson Ultimate Chopper              46
# 24    1969 Harley Davidson Ultimate Chopper              48
# 25    1969 Harley Davidson Ultimate Chopper              49
# 26    1969 Harley Davidson Ultimate Chopper              59
# 27    1969 Harley Davidson Ultimate Chopper              66
# 28                 1952 Alpine Renault 1300              21
# 29                 1952 Alpine Renault 1300              21
# ...                                     ...             ...
# 2966                       Boeing X-32A JSF              48
# 2967                       Boeing X-32A JSF              49
# 2968                       Boeing X-32A JSF              50
# 2969                             Pont Yacht              20
# 2970                             Pont Yacht              23
# 2971                             Pont Yacht              24
# 2972                             Pont Yacht              25
# 2973                             Pont Yacht              28
# 2974                             Pont Yacht              29
# 2975                             Pont Yacht              29
# 2976                             Pont Yacht              31
# 2977                             Pont Yacht              32
# 2978                             Pont Yacht              32
# 2979                             Pont Yacht              33
# 2980                             Pont Yacht              34
# 2981                             Pont Yacht              35
# 2982                             Pont Yacht              36
# 2983                             Pont Yacht              37
# 2984                             Pont Yacht              37
# 2985                             Pont Yacht              38
# 2986                             Pont Yacht              39
# 2987                             Pont Yacht              40
# 2988                             Pont Yacht              40
# 2989                             Pont Yacht              42
# 2990                             Pont Yacht              42
# 2991                             Pont Yacht              42
# 2992                             Pont Yacht              43
# 2993                             Pont Yacht              47
# 2994                             Pont Yacht              50
# 2995                             Pont Yacht              50
#
# [2996 rows x 2 columns]

# %% [markdown]
# ## Select the Product Name and the  Total Number of People Who Have Ordered Each Product
#
# Sort the results in descending order.

# %%
#Your code here

# %% [markdown]
# ## Select the Employee Number, Office Code, City (of the office), and Name (First and Last) of those Employees who Sold Products that Have Been Ordered by Less Then 20 people.
#
# This problem is a bit tougher. To start, think about how you might break the problem up. Be sure that your results only list each employee once.

# %%
#Your code here

c.execute("""SELECT employeeNumber, officeCode, offices.city,
            lastName, firstName FROM 
            (SELECT employeeNumber FROM employees
            JOIN customers ON employees.employeeNumber = customers.salesRepEmployeeNumber
            
            
            
            
            
            """)

# %% [markdown]
# ## Select the Employee Number, Name (First and Last) and Number of Customers of Employees Who's Customers Have an Average Credit Limit of Over 15K

# %%
#Your code here



c.execute("""SELECT employeeNumber, lastName, firstName 
                """)

# %% [markdown]
# ## Summary
#
# In this lesson, you got to practice some more complex SQL queries, some of which required subqueries. There's still plenty more SQL to be had though; hope you've been enjoying some of these puzzles!
